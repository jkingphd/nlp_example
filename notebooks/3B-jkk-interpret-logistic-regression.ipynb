# %% [markdown]
# # 3B-jkk-interpret-logistic-regression
#
# In this notebook, we will explore global and local explanations for an [interpretable model](https://christophm.github.io/interpretable-ml-book/simple.html) (Logistic Regression). We will also delve into techniques for presenting explanations to end users. Note that these local global and local explanations are unique to linear models, and other models will require other strategies.
#
# Note that the documentation linked above may refer to a newer version of scikit-learn.

# %%
# %config IPCompleter.use_jedi = False

from IPython.display import HTML
from joblib import load
import sqlite3 as sql
import pandas as pd
import numpy as np
import re

seed = 101

# %% [markdown]
# Load the entire dataset.

# %%
with sql.connect('../data/toxic.db') as conn:
    df = pd.read_sql_query('''select * from toxic''', conn)
df.head()
# Out:
#     rev_id                                            comment  year  \
# 0   2232.0  This:\n:One can make an analogy in mathematica...  2002
# 1   4216.0  "\n\n:Clarification for you  (and Zundark's ri...  2002
# 2   8953.0                          Elected or Electoral? JHK  2002
# 3  26547.0  "This is such a fun entry.   Devotchka\n\nI on...  2002
# 4  28959.0  Please relate the ozone hole to increases in c...  2002
#
#    logged_in       ns  sample  split   num  min  max  avg  y
# 0          1  article  random  train  10.0 -1.0  1.0  0.4  0
# 1          1     user  random  train  10.0  0.0  2.0  0.5  0
# 2          0  article  random   test  10.0  0.0  1.0  0.1  0
# 3          1  article  random  train  10.0  0.0  2.0  0.6  0
# 4          1  article  random   test  10.0 -1.0  1.0  0.2  0

# %% [markdown]
# Split into two seperate dataframes: df_train and df_test.

# %%
df_train = df[df['split'] == 'train'].copy().reset_index(drop=True)
df_train.head()
# Out:
#     rev_id                                            comment  year  \
# 0   2232.0  This:\n:One can make an analogy in mathematica...  2002
# 1   4216.0  "\n\n:Clarification for you  (and Zundark's ri...  2002
# 2  26547.0  "This is such a fun entry.   Devotchka\n\nI on...  2002
# 3  37330.0  "\n\n\nI fixed the link; I also removed ""home...  2002
# 4  37346.0  "If they are ""indisputable"" then why does th...  2002
#
#    logged_in       ns  sample  split   num  min  max  avg  y
# 0          1  article  random  train  10.0 -1.0  1.0  0.4  0
# 1          1     user  random  train  10.0  0.0  2.0  0.5  0
# 2          1  article  random  train  10.0  0.0  2.0  0.6  0
# 3          1  article  random  train  10.0 -1.0  1.0  0.1  0
# 4          1  article  random  train  10.0 -1.0  1.0  0.2  0

# %%
df_test = df[df['split'] == 'test'].copy().reset_index(drop=True)
df_test.head()
# Out:
#      rev_id                                            comment  year  \
# 0    8953.0                          Elected or Electoral? JHK  2002
# 1   28959.0  Please relate the ozone hole to increases in c...  2002
# 2  138074.0  "\n\n\n\nI'm not sure if it's properly called ...  2002
# 3  200664.0  \n\n\n \nThanks on the info on how to move a p...  2002
# 4  213105.0  "\n\n: I should do that too, I agree, but I've...  2002
#
#    logged_in       ns  sample split   num  min  max  avg  y
# 0          0  article  random  test  10.0  0.0  1.0  0.1  0
# 1          1  article  random  test  10.0 -1.0  1.0  0.2  0
# 2          1  article  random  test  10.0  0.0  1.0  0.5  0
# 3          1     user  random  test  10.0  0.0  1.0  0.4  0
# 4          1     user  random  test  10.0  0.0  1.0  0.3  0

# %% [markdown]
# Let's grab our best Logistic Regression model from notebook 2B-jkk-logistic-regression.

# %%
rs = load('../results/rs_cv_lr.joblib')
pipe = rs.best_estimator_
pipe.steps
# Out:
# [('vect',
#   TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#           dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#           lowercase=True, max_df=1.0, max_features=None, min_df=5,
#           ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#           stop_words=None, strip_accents=None, sublinear_tf=False,
#           token_pattern='[a-z]+', tokenizer=None, use_idf=True,
#           vocabulary=None)),
#  ('select',
#   SelectPercentile(percentile=10,
#            score_func=<function chi2 at 0x000001F52A1C72F0>)),
#  ('clf',
#   LogisticRegression(C=10.0, class_weight=None, dual=False, fit_intercept=True,
#             intercept_scaling=1, max_iter=100, multi_class='warn',
#             n_jobs=None, penalty='l2', random_state=None, solver='warn',
#             tol=0.0001, verbose=0, warm_start=False))]

# %% [markdown]
# Before we go any further, let's go ahead and generate predictions on the test set so we have some examples for later.

# %%
df_test["y_prob"] = pipe.predict_proba(df_test["comment"])[:,1]
df_test["y_pred"] = (df_test["y_prob"] > 0.5).astype(int)
df_test.head()
# Out:
#      rev_id                                            comment  year  \
# 0    8953.0                          Elected or Electoral? JHK  2002
# 1   28959.0  Please relate the ozone hole to increases in c...  2002
# 2  138074.0  "\n\n\n\nI'm not sure if it's properly called ...  2002
# 3  200664.0  \n\n\n \nThanks on the info on how to move a p...  2002
# 4  213105.0  "\n\n: I should do that too, I agree, but I've...  2002
#
#    logged_in       ns  sample split   num  min  max  avg  y    y_prob  y_pred
# 0          0  article  random  test  10.0  0.0  1.0  0.1  0  0.128771       0
# 1          1  article  random  test  10.0 -1.0  1.0  0.2  0  0.555851       1
# 2          1  article  random  test  10.0  0.0  1.0  0.5  0  0.029366       0
# 3          1     user  random  test  10.0  0.0  1.0  0.4  0  0.014342       0
# 4          1     user  random  test  10.0  0.0  1.0  0.3  0  0.024154       0

# %% [markdown]
# Our best result from the random search has a select step, which means that we will need to apply the mask obtained in the select step to the output of the vectorizer. Let's start by grabbing copies of the named steps in the pipeline, to make things easier to work with.

# %%
vect = pipe.named_steps['vect']
select = pipe.named_steps['select']
clf = pipe.named_steps['clf']

# %%
len(vect.vocabulary_)
# Out:
# 30713

# %%
len(clf.coef_[0])
# Out:
# 3072

# %% [markdown]
# We know that the select step only keeps 10% of the input features. We can extract the mask from the SelectPercentile object, but it is a hidden variable (note the leading underscore).

# %%
vect_mask = select._get_support_mask()
vect_mask
# Out:
# array([False, False, False, ..., False, False, False])

# %%
vect_mask.mean()
# Out:
# 0.10002279165174356

# %% [markdown]
# From here, let's dump the vocabulary and coefficient for each term from the model so that we can examine **global** behavior.

# %%
vocab = vect.get_feature_names()
vocab = np.array(vocab)[vect_mask]
vocab[:5]
# Out:
# array(['abd', 'able', 'abomination', 'about', 'above'], dtype='<U23')

# %%
df_global = pd.DataFrame(
    {
        "token":vocab,
        "coef":clf.coef_[0]
    }
)
df_global.head()
# Out:
#          token      coef
# 0          abd  1.855428
# 1         able -1.043615
# 2  abomination  5.311582
# 3        about -1.280364
# 4        above -0.534324

# %% [markdown]
# We can now sort by coef to examine the most important factors to the non-toxic and toxic classes. High coefficients are associated with the toxic class. Low (i.e., negative) coefficients are associated with the non-toxic class. Let's start by looking at the non-toxic class.

# %%
df_global = df_global.sort_values("coef", ascending=True)
df_global.head(10)
# Out:
#            token      coef
# 2692       thank -9.985196
# 2693      thanks -8.721378
# 2367     setting -5.214016
# 1649      merged -4.875996
# 2604     success -4.840157
# 1810  noteworthy -4.287727
# 2004      plural -4.203437
# 1185      health -4.136181
# 1213    historic -4.118104
# 938     feedback -4.087447

# %% [markdown]
# Nice, what about the other end?

# %%
df_global.tail(10)
# Out:
#          token       coef
# 1700     moron  13.833806
# 332   bullshit  14.714231
# 1280     idiot  15.148265
# 243      bitch  15.525072
# 557       crap  15.639011
# 139        ass  15.884015
# 2591    stupid  17.277218
# 2389      shit  19.169719
# 1027   fucking  21.629195
# 1018      fuck  27.375162

# %% [markdown]
# Well, this aligns with expectations. On the other hand, these are really **global** weights, and while they are useful for understanding general model behavior, what if we want to understand a **specific** prediction? In that case, we need to compute the activation, or the product of the coefficient with the weight from the bag of words representation. Let's write a helper function to do just that.

# %%
def get_activations(text, vect=vect, select=select, clf=clf):
    """Returns a list of tokens, their coefficients, and output activations for a given input."""
    x = vect.transform([text])
    x_sub = select.transform(x)
    x_out = np.multiply(x_sub.toarray()[0], clf.coef_[0])
    vect_mask = select._get_support_mask()
    vocab = vect.get_feature_names()
    vocab = np.array(vocab)[vect_mask]
    df_local = pd.DataFrame(
        {
            "token":vocab,
            "weight":x_sub.toarray()[0],
            "coef":clf.coef_[0]
        }
    )
    df_local = df_local[df_local["weight"] != 0]
    df_local["activation"] = df_local["weight"]*df_local["coef"]
    return df_local

# %% [markdown]
# How does it work? Let's grab an example from the test set where we successfully predicted the correct answer.

# %%
idx = df_test["y"] == df_test["y_pred"]
df_test[idx].sample(10, random_state=seed)
# Out:
#             rev_id                                            comment  year  \
# 3167    52759277.0  Perhaps the overwhelming evidence points to Ko...  2006
# 27401  566125445.0  "\n\n== Pakistan ==\n\nPlease do not add  to a...  2013
# 19996  360915404.0  Go fuck yourself you stupid bitch go do someth...  2010
# 1295    27406343.0    you need to fuck off and stop hrassing people\n  2005
# 18505  325668254.0  \n:::: The problem with any use of the word 'i...  2009
# 5706    86778622.0  A tag has been placed on Snake Net, requesting...  2006
# 2167    39845384.0  \n\n== Alumni lists ==\n\nHi coblin, check out...  2006
# 17302  300709731.0  \n\n== More efficient answer ==\n\nWhat you wr...  2009
# 29846  637441859.0  " \n\n Thanks for the review and comments, my ...  2014
# 25976  518999012.0  \n\n:Whatever, man. I wouldn't call that edit ...  2012
#
#        logged_in       ns   sample split   num  min  max  avg  y    y_prob  \
# 3167           1  article   random  test  10.0  0.0  1.0  0.7  0  0.015011
# 27401          1     user   random  test  10.0 -1.0  1.0  0.1  0  0.100116
# 19996          0     user  blocked  test  10.0 -2.0 -1.0 -1.6  1  0.999996
# 1295           0     user  blocked  test  10.0 -2.0 -1.0 -1.3  1  1.000000
# 18505          1  article  blocked  test  10.0  0.0  1.0  0.4  0  0.060003
# 5706           1     user   random  test  10.0  0.0  1.0  0.7  0  0.000759
# 2167           1     user   random  test  10.0  0.0  2.0  1.0  0  0.021811
# 17302          1     user   random  test  10.0 -1.0  1.0  0.1  0  0.024006
# 29846          1     user   random  test  10.0  0.0  1.0  0.8  0  0.003742
# 25976          1     user  blocked  test  10.0 -1.0  1.0 -0.1  1  0.769937
#
#        y_pred
# 3167        0
# 27401       0
# 19996       1
# 1295        1
# 18505       0
# 5706        0
# 2167        0
# 17302       0
# 29846       0
# 25976       1

# %%
sample_text = df_test.loc[25976, "comment"]
print(sample_text)
# Out:
# :Whatever, man. I wouldn't call that edit warring, and yeah, I had no idea you couldn't point out that someone is lying when they are. It's a shame because I give a lot to this site. I make improvements where I see they're needed. This block and unnecessary and quite silly to be honest. But whatever. You're the man with the power.

# %%
df_local = get_activations(sample_text)
df_local
# Out:
#          token    weight      coef  activation
# 76         and  0.137574  0.467370    0.064298
# 109        are  0.064288  2.153097    0.138418
# 207         be  0.059559  0.746915    0.044485
# 258      block  0.125874  1.149485    0.144690
# 342        but  0.068425 -2.917966   -0.199660
# 350       call  0.142085  0.183539    0.026078
# 808       edit  0.095172 -0.243452   -0.023170
# 1078      give  0.126470  0.276692    0.034993
# 1141       had  0.104769  0.346565    0.036309
# 1274         i  0.221984 -0.506888   -0.112521
# 1277      idea  0.137874 -1.344672   -0.185395
# 1377        is  0.048781  0.843983    0.041171
# 1385        it  0.050338 -1.188022   -0.059802
# 1575       lot  0.133024 -1.912019   -0.254345
# 1588     lying  0.189664  2.885093    0.547197
# 1604       man  0.281532  1.021663    0.287630
# 1756    needed  0.151266 -0.507107   -0.076708
# 2008     point  0.112106 -1.564853   -0.175430
# 2036     power  0.154947  0.972467    0.150681
# 2132     quite  0.134569 -0.959558   -0.129126
# 2159        re  0.200978  1.079915    0.217039
# 2291         s  0.064387 -0.121689   -0.007835
# 2344       see  0.087555 -1.730710   -0.151533
# 2380     shame  0.190739  6.325640    1.206546
# 2423     silly  0.180224  6.581107    1.186071
# 2645         t  0.133228  0.575344    0.076652
# 2694      that  0.102284 -0.896676   -0.091716
# 2696       the  0.076321 -1.197522   -0.091396
# 2709      this  0.113143  0.253333    0.028663
# 2742        to  0.083078 -1.188475   -0.098736
# 2950  whatever  0.296541  0.134147    0.039780
# 2953     where  0.108005 -0.564180   -0.060934
# 3000      with  0.066496 -0.269732   -0.017936
# 3044      yeah  0.159097  0.875798    0.139337
# 3053       you  0.095106  4.201974    0.399633

# %% [markdown]
# Finally, let's use this information to augment the original text and highlight the keywords that are driving the decision.

# %%
target = "lying"
activation = 0.547197
sample_text_out = re.sub(f"\\b{target}\\b", f"<mark>{target}</mark>", sample_text)
HTML(sample_text_out)
# Out:
# :Whatever, man. I wouldn't call that edit warring, and yeah, I had no idea you couldn't point out that someone is <mark>lying</mark> when they are. It's a shame because I give a lot to this site. I make improvements where I see they're needed. This block and unnecessary and quite silly to be honest. But whatever. You're the man with the power.

# %% [markdown]
# We can expand this methodology to create a heat-map showing where the components of the message associated with each class are located.

# %%
def highlight_text(text, df_local):
    # Create a scaling factor for this local explanation
    alpha = 0.5/np.max(np.abs(df_local['activation']))
#     text_out = text
    for token, activation in df_local[["token", "activation"]].values:
        # Start by locating all instances of the token (ignoring case)
        targets = re.findall(f"\\b{token}\\b", text, flags=re.IGNORECASE)
        targets = set(targets)
        # Loop over each unique case and sub with a mark tag that is color-coded to indicate class contribution
        for target in targets:
            if activation > 0:
                text = re.sub(
                    f"\\b{target}\\b",
                    f"""<mark style="background-color:rgba(255,0,0,{alpha*activation});">{target}</mark>""",
                    text
                )
            else:
                text = re.sub(
                    f"\\b{target}\\b",
                    f"""<mark style="background-color:rgba(0,0,255,{-1*alpha*activation});">{target}</mark>""",
                    text
                )
    return text

text_out = highlight_text(sample_text, df_local)
HTML("<pre>" + text_out + "</pre>")
# Out:
# <pre>
#
# :<mark style="background-color:rgba(255,0,0,0.0164850991897186);">Whatever</mark>, <mark style="background-color:rgba(255,0,0,0.11919572205349185);">man</mark>. <mark style="background-color:rgba(0,0,255,0.04662947503942937);">I</mark> wouldn'<mark style="background-color:rgba(255,0,0,0.031764977902783896);">t</mark> <mark style="background-color:rgba(255,0,0,0.010806936097553269);">call</mark> <mark style="background-color:rgba(0,0,255,0.038007668508788776);">that</mark> <mark style="background-color:rgba(0,0,255,0.009601728783141854);">edit</mark> warring, <mark style="background-color:rgba(255,0,0,0.026645417726481033);">and</mark> <mark style="background-color:rgba(255,0,0,0.05774191418536013);">yeah</mark>, <mark style="background-color:rgba(0,0,255,0.04662947503942937);">I</mark> <mark style="background-color:rgba(255,0,0,0.015046725624570049);">had</mark> no <mark style="background-color:rgba(0,0,255,0.07682863335143916);">idea</mark> <mark style="background-color:rgba(255,0,0,0.16561048714651186);">you</mark> couldn'<mark style="background-color:rgba(255,0,0,0.031764977902783896);">t</mark> <mark style="background-color:rgba(0,0,255,0.07269910019104779);">point</mark> out <mark style="background-color:rgba(0,0,255,0.038007668508788776);">that</mark> someone <mark style="background-color:rgba(255,0,0,0.017061403466077697);">is</mark> <mark style="background-color:rgba(255,0,0,0.22676179686297024);">lying</mark> when they <mark style="background-color:rgba(255,0,0,0.05736136149251316);">are</mark>. <mark style="background-color:rgba(0,0,255,0.02478244479820557);">It</mark>'<mark style="background-color:rgba(0,0,255,0.0032469685493735014);">s</mark> a <mark style="background-color:rgba(255,0,0,0.5);">shame</mark> because <mark style="background-color:rgba(0,0,255,0.04662947503942937);">I</mark> <mark style="background-color:rgba(255,0,0,0.014501462145356008);">give</mark> a <mark style="background-color:rgba(0,0,255,0.10540192005560305);">lot</mark> <mark style="background-color:rgba(0,0,255,0.04091673542810736);">to</mark> <mark style="background-color:rgba(255,0,0,0.011878080466922885);">this</mark> site. <mark style="background-color:rgba(0,0,255,0.04662947503942937);">I</mark> make improvements <mark style="background-color:rgba(0,0,255,0.0252515870722);">where</mark> <mark style="background-color:rgba(0,0,255,0.04662947503942937);">I</mark> <mark style="background-color:rgba(0,0,255,0.06279625100285012);">see</mark> they'<mark style="background-color:rgba(255,0,0,0.08994239695426066);">re</mark> <mark style="background-color:rgba(0,0,255,0.031788255531180885);">needed</mark>. <mark style="background-color:rgba(255,0,0,0.011878080466922885);">This</mark> <mark style="background-color:rgba(255,0,0,0.05996059299753365);">block</mark> <mark style="background-color:rgba(255,0,0,0.026645417726481033);">and</mark> unnecessary <mark style="background-color:rgba(255,0,0,0.026645417726481033);">and</mark> <mark style="background-color:rgba(0,0,255,0.05351075109511253);">quite</mark> <mark style="background-color:rgba(255,0,0,0.49151494790296124);">silly</mark> <mark style="background-color:rgba(0,0,255,0.04091673542810736);">to</mark> <mark style="background-color:rgba(255,0,0,0.018435046655901354);">be</mark> honest. <mark style="background-color:rgba(0,0,255,0.08274047340108735);">But</mark> <mark style="background-color:rgba(255,0,0,0.0164850991897186);">whatever</mark>. <mark style="background-color:rgba(255,0,0,0.16561048714651186);">You</mark>'<mark style="background-color:rgba(255,0,0,0.08994239695426066);">re</mark> <mark style="background-color:rgba(0,0,255,0.03787508873017522);">the</mark> <mark style="background-color:rgba(255,0,0,0.11919572205349185);">man</mark> <mark style="background-color:rgba(0,0,255,0.00743284683554942);">with</mark> <mark style="background-color:rgba(0,0,255,0.03787508873017522);">the</mark> <mark style="background-color:rgba(255,0,0,0.06244319596598215);">power</mark>.   </pre>

# %% [markdown]
# It works! What about a more nuanced example?

# %%
idx = (df_test["y_prob"] > 0.49) & (df_test["y_prob"] < 0.51) & (df_test["comment"].str.len() > 500)
df_test[idx].sample(10, random_state=seed)
# Out:
#             rev_id                                            comment  year  \
# 29743  634282094.0  "\n\n== The American Agenda to Homosexualize t...  2014
# 6812   105173339.0  \n\nI find your accusations of vandalism rudel...  2007
# 7819   122922847.0   April 2007 (UTC)\n\n::I got banned for being ...  2007
# 28073  588021858.0  \n\n::Ha, what you said was a lie, when you ma...  2013
# 26208  527241171.0  ", 9 December 2012 (UTC)\n\n::I find it far fr...  2012
# 10653  176630870.0  \n\n== Congratulations! ==\n\nI have awarded y...  2007
# 4559    69491148.0  "You lying SOB==\n""I don't focus on single ar...  2006
# 10193  168373112.0  "\n\nI think the entire article should be tagg...  2007
# 21004  384129495.0  "\n\n:::If Either way chooses to disregard my ...  2010
# 17743  308970708.0  "\n\n==I need ""temperance""?==\n\nYou don't k...  2009
#
#        logged_in       ns   sample split   num  min  max  avg  y    y_prob  \
# 29743          1  article  blocked  test  10.0 -2.0  1.0 -0.4  1  0.509101
# 6812           0     user  blocked  test  10.0 -1.0  1.0  0.1  0  0.506900
# 7819           0  article  blocked  test  10.0 -1.0  1.0  0.1  0  0.492678
# 28073          0     user  blocked  test  10.0 -1.0  1.0 -0.4  1  0.500344
# 26208          0  article  blocked  test  10.0 -2.0  1.0  0.1  0  0.493297
# 10653          1     user  blocked  test  10.0  0.0  2.0  0.6  0  0.495029
# 4559           0     user  blocked  test  10.0 -2.0  1.0 -0.6  1  0.499364
# 10193          1  article   random  test  10.0 -1.0  1.0  0.2  0  0.490501
# 21004          1     user  blocked  test  10.0 -1.0  1.0  0.3  0  0.490374
# 17743          1     user  blocked  test  10.0 -1.0  1.0  0.0  0  0.499381
#
#        y_pred
# 29743       1
# 6812        1
# 7819        0
# 28073       1
# 26208       0
# 10653       0
# 4559        0
# 10193       0
# 21004       0
# 17743       0

# %%
sample_text = df_test.loc[6812, "comment"]
df_local = get_activations(sample_text)
text_out = highlight_text(sample_text, df_local)
HTML("<pre>" + text_out + "</pre>")
# Out:
# <pre>
#
# <mark style="background-color:rgba(0,0,255,0.02700986456117945);">I</mark> <mark style="background-color:rgba(0,0,255,0.021634920260720565);">find</mark> <mark style="background-color:rgba(255,0,0,0.025440127339130196);">your</mark> accusations <mark style="background-color:rgba(0,0,255,0.0016335199468719228);">of</mark> <mark style="background-color:rgba(255,0,0,0.03377728069278962);">vandalism</mark> <mark style="background-color:rgba(255,0,0,0.07184228831715232);">rudely</mark> appauling <mark style="background-color:rgba(0,0,255,0.07702757352745077);">to</mark> <mark style="background-color:rgba(255,0,0,0.024314088543356076);">all</mark> users.
# <mark style="background-color:rgba(255,0,0,0.33575134362643716);">You</mark> <mark style="background-color:rgba(0,0,255,0.0004006919223209878);">have</mark> <mark style="background-color:rgba(0,0,255,0.01643501906082246);">articles</mark> <mark style="background-color:rgba(0,0,255,0.021611388035696916);">accepted</mark> <mark style="background-color:rgba(0,0,255,0.026242459778840637);">which</mark> <mark style="background-color:rgba(255,0,0,0.004357866144377665);">had</mark> <mark style="background-color:rgba(0,0,255,0.0148832001447165);">altered</mark> <mark style="background-color:rgba(0,0,255,0.015021063559602088);">dates</mark> <mark style="background-color:rgba(0,0,255,0.03302359648614499);">that</mark> belong solely <mark style="background-color:rgba(0,0,255,0.07702757352745077);">to</mark> <mark style="background-color:rgba(0,0,255,0.049362603502488694);">the</mark> WatchTower
# inserted <mark style="background-color:rgba(0,0,255,0.01194325804788953);">into</mark> <mark style="background-color:rgba(0,0,255,0.004272495087393122);">other</mark> chornologies <mark style="background-color:rgba(0,0,255,0.02466836359767255);">creating</mark> disharmony. <mark style="background-color:rgba(0,0,255,0.02700986456117945);">I</mark> attempt <mark style="background-color:rgba(0,0,255,0.07702757352745077);">to</mark> <mark style="background-color:rgba(0,0,255,0.06898231727393266);">separate</mark> <mark style="background-color:rgba(0,0,255,0.049362603502488694);">the</mark> <mark style="background-color:rgba(0,0,255,0.00924351029720836);">two</mark> so <mark style="background-color:rgba(0,0,255,0.049362603502488694);">the</mark> <mark style="background-color:rgba(0,0,255,0.003981237718694578);">reader</mark>
# understands <mark style="background-color:rgba(255,0,0,0.004818693448096173);">why</mark> <mark style="background-color:rgba(0,0,255,0.049362603502488694);">the</mark> <mark style="background-color:rgba(0,0,255,0.08703339742017337);">conflict</mark> <mark style="background-color:rgba(255,0,0,0.030868420601336027);">and</mark> <mark style="background-color:rgba(255,0,0,0.33575134362643716);">YOU</mark> <mark style="background-color:rgba(0,0,255,0.007511290791745768);">replace</mark> <mark style="background-color:rgba(0,0,255,0.05024282750876977);">it</mark> back <mark style="background-color:rgba(0,0,255,0.07702757352745077);">to</mark> <mark style="background-color:rgba(255,0,0,0.006769797305381309);">what</mark> <mark style="background-color:rgba(0,0,255,0.05024282750876977);">it</mark> <mark style="background-color:rgba(0,0,255,0.017241291835222917);">was</mark> <mark style="background-color:rgba(0,0,255,0.010666628449868518);">in</mark> <mark style="background-color:rgba(0,0,255,0.08703339742017337);">conflict</mark>, <mark style="background-color:rgba(0,0,255,0.0028710922671879415);">some</mark> WatchTower
# know <mark style="background-color:rgba(0,0,255,0.05024282750876977);">it</mark> <mark style="background-color:rgba(255,0,0,0.024314088543356076);">all</mark> conflicting <mark style="background-color:rgba(0,0,255,0.008610870534674495);">with</mark> secular scholars <mark style="background-color:rgba(255,0,0,0.030868420601336027);">and</mark> Ussher. <mark style="background-color:rgba(255,0,0,0.33575134362643716);">You</mark> <mark style="background-color:rgba(0,0,255,0.021634920260720565);">find</mark> <mark style="background-color:rgba(255,0,0,0.047441175872102705);">fault</mark> <mark style="background-color:rgba(0,0,255,0.008610870534674495);">with</mark> <mark style="background-color:rgba(255,0,0,0.05011961644760304);">me</mark> <mark style="background-color:rgba(255,0,0,0.030868420601336027);">and</mark> <mark style="background-color:rgba(255,0,0,0.004662262958272877);">not</mark> <mark style="background-color:rgba(0,0,255,0.049362603502488694);">the</mark>
# <mark style="background-color:rgba(0,0,255,0.005241119976482884);">info</mark> <mark style="background-color:rgba(0,0,255,0.026242459778840637);">which</mark> <mark style="background-color:rgba(0,0,255,0.009206585274735985);">needed</mark> correcting. <mark style="background-color:rgba(0,0,255,0.02700986456117945);">I</mark> <mark style="background-color:rgba(0,0,255,0.014547558523916778);">further</mark> <mark style="background-color:rgba(255,0,0,0.004198547206555591);">corrected</mark> <mark style="background-color:rgba(0,0,255,0.049362603502488694);">the</mark> <mark style="background-color:rgba(0,0,255,0.014327820216502578);">claim</mark> <mark style="background-color:rgba(0,0,255,0.03302359648614499);">that</mark> Caesar'<mark style="background-color:rgba(0,0,255,0.0009403942536220844);">s</mark> 29 AD <mark style="background-color:rgba(0,0,255,0.017241291835222917);">was</mark> Gregorian <mark style="background-color:rgba(0,0,255,0.005027673216364276);">by</mark>'
# changing <mark style="background-color:rgba(0,0,255,0.05024282750876977);">it</mark> <mark style="background-color:rgba(0,0,255,0.07702757352745077);">to</mark> Julian, <mark style="background-color:rgba(255,0,0,0.030868420601336027);">and</mark> <mark style="background-color:rgba(255,0,0,0.33575134362643716);">you</mark> <mark style="background-color:rgba(0,0,255,0.03425907856051673);">changed</mark> <mark style="background-color:rgba(0,0,255,0.03302359648614499);">that</mark> back too. <mark style="background-color:rgba(255,0,0,0.006880312171369973);">This</mark> <mark style="background-color:rgba(255,0,0,0.00494136162215773);">is</mark> <mark style="background-color:rgba(0,0,255,0.017250237409616193);">on</mark> record so <mark style="background-color:rgba(0,0,255,0.03302359648614499);">that</mark> <mark style="background-color:rgba(0,0,255,0.02700986456117945);">i</mark> <mark style="background-color:rgba(0,0,255,0.007548184158301723);">can</mark> preent <mark style="background-color:rgba(255,0,0,0.006880312171369973);">this</mark> publicly
# <mark style="background-color:rgba(0,0,255,0.017250237409616193);">on</mark> how <mark style="background-color:rgba(255,0,0,0.33575134362643716);">you</mark> do <mark style="background-color:rgba(255,0,0,0.004662262958272877);">not</mark> build knowledge <mark style="background-color:rgba(0,0,255,0.008610870534674495);">with</mark> <mark style="background-color:rgba(255,0,0,0.013093700895318245);">Wikipedia</mark> <mark style="background-color:rgba(0,0,255,0.02396347994912564);">but</mark> <mark style="background-color:rgba(255,0,0,0.0008600010000059177);">rather</mark> <mark style="background-color:rgba(255,0,0,0.33575134362643716);">you</mark> <mark style="background-color:rgba(255,0,0,0.076406967946019);">destroy</mark> <mark style="background-color:rgba(0,0,255,0.05024282750876977);">it</mark> <mark style="background-color:rgba(0,0,255,0.005027673216364276);">by</mark> <mark style="background-color:rgba(255,0,0,0.0013046367704950613);">these</mark> games <mark style="background-color:rgba(0,0,255,0.007313420815891931);">where</mark> <mark style="background-color:rgba(255,0,0,0.33575134362643716);">you</mark>
# <mark style="background-color:rgba(0,0,255,0.003655159708174733);">use</mark> <mark style="background-color:rgba(255,0,0,0.018084937310383718);">power</mark> <mark style="background-color:rgba(0,0,255,0.07702757352745077);">to</mark> rule <mark style="background-color:rgba(255,0,0,0.030868420601336027);">and</mark> <mark s

# %% [markdown]
# This is a powerful method of building trust among end users, and is useful for model training. However, we should note that this method starts to break down when you have features that span the same token multiple times (i.e., n-grams!). This heat-map approach might require layering at the individual character level, but that is left as an exercise to the reader.
